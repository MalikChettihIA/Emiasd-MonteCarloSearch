# %% [markdown]
# # Nested for Expression Discovery

# %%
import numpy as np
import random
import math
import copy

# %%
atoms = [1, 2, 3, '+', '-']
children = [0, 0, 0, 2, 2]
MaxLength = 11

def legalMoves (state, leaves):
    l = []
    for a in range (len (atoms)):
        if len (state) + leaves + children [a] <= MaxLength:
            l.append (a)
    return l

def play (state, move, leaves):
    state.append (move)
    return [state, leaves - 1 + children [move]]

def terminal (state, leaves):
    return leaves == 0

def score (state, i):
    if children [state [i]] == 0:
        return [atoms [state [i]], i + 1]
    if children [state [i]] == 2:
        a = atoms [state [i]]
        [s1,i] = score (state, i + 1)
        [s2,i] = score (state, i)
        if a == '+':
            return [s1 + s2, i]
        if a == '-':
            return [s1 - s2, i]

# %%
def playout (state, leaves):
    while not terminal (state, leaves):
        moves = legalMoves (state, leaves)
        move = moves [int(random.random () * len (moves))]
        [state, leaves] = play (state, move, leaves)
    return state

def nested (state, leaves, n):
    bestSequence = []
    bestScore = -10e9
    while not terminal (state, leaves):
        moves = legalMoves (state, leaves)
        for m in moves:
            s1 = copy.deepcopy (state)
            [s1, leaves1] = play (s1, m, leaves)
            if (n == 1):
                s1 = playout (s1, leaves1)
            else:
                s1 = nested (s1, leaves1, n - 1)
            [score1, i] = score (s1, 0)
            if score1 > bestScore:
                bestScore = score1
                bestSequence = s1
        [state, leaves] = play (state, bestSequence [len (state)], leaves)
    return state

# %%
import sys

def printExpression (state):
    for i in state:
        sys.stdout.write (str (atoms [i]) + ' ')
    sys.stdout.write ('\n')
    
def test ():
    for i in range (10):
        s = playout ([], 1)
        printExpression (s)
        print (score (s, 0) [0])
    for i in range (10):
        s = nested ([], 1, 2)
        printExpression (s)
        print (score (s, 0) [0])

test ()
# Out:
# + - 1 1 - 2 3
# -1
# + + + 2 3 3 - 1 1
# 8
# 2
# 2
# + 3 3
# 6
# 2
# 2
# 2
# 2
# 1
# 1
# 3
# 3
# 1
# 1
# + 2 - 3 2
# 3
# + 1 + + + 3 3 + 3 3 3
# 16
# + 3 + + + 3 3 + 3 3 3
# 18
# - 2 - - 1 3 + + 3 3 3
# 13
# + 2 + + 3 3 + + 3 3 3
# 17
# + + 3 + 3 + + 3 3 3 3
# 18
# + + + 3 + 3 + 3 3 3 3
# 18
# - + + 3 + 3 + 3 3 3 1
# 14
# + + 3 3 + 3 + + 3 3 3
# 18
# + + 3 3 + + 3 + 3 3 3
# 18
# + 3 + + + + 3 3 3 3 3
# 18

# %% [markdown]
# # Discovery of Exploration Terms

# %%
# !wget https://www.lamsade.dauphine.fr/~cazenave/generate.zip
# !unzip generate.zip
# Out:
# --2025-03-11 16:34:46--  https://www.lamsade.dauphine.fr/~cazenave/generate.zip
# Résolution de www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)… 193.48.71.250
# Connexion à www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)|193.48.71.250|:443… connecté.
# requête HTTP transmise, en attente de la réponse… 200 OK
# Taille : 183517862 (175M) [application/zip]
# Enregistre : ‘generate.zip’
#
# generate.zip        100%[===================>] 175,02M   870KB/s    ds 3m 34s
#
# 2025-03-11 16:38:21 (836 KB/s) - ‘generate.zip’ enregistré [183517862/183517862]
#
# Archive:  generate.zip
#    creating: generate/
#   inflating: generate/946.data
#   inflating: generate/487.data
#   inflating: generate/636.data
#   inflating: generate/286.data
#   inflating: generate/651.data
#   inflating: generate/1026.data
#   inflating: generate/976.data
#   inflating: generate/762.data
#   inflating: generate/72.data
#   inflating: generate/167.data
#   inflating: generate/1442.data
#   inflating: generate/650.data
#   inflating: generate/918.data
#   inflating: generate/921.data
#   inflating: generate/1064.data
#   inflating: generate/1656.data
#   inflating: generate/606.data
#   inflating: generate/367.data
#   inflating: generate/1323.data
#   inflating: generate/1431.data
#   inflating: generate/1443.data
#   inflating: generate/833.data
#   inflating: generate/337.data
#   inflating: generate/1616.data
#   inflating: generate/1697.data
#   inflating: generate/1554.data
#   inflating: generate/1202.data
#   inflating: generate/1216.data
#   inflating: generate/848.data
#   inflating: generate/1081.data
#   inflating: generate/875.data
#   inflating: generate/1597.data
#   inflating: generate/993.data
#   inflating: generate/676.data
#   inflating: generate/1496.data
#   inflating: generate/1204.data
#   inflating: generate/1688.data
#   inflating: generate/1002.data
#   inflating: generate/67.data
#   inflating: generate/1647.data
#   inflating: generate/308.data
#  extracting: generate/1689.data
#   inflating: generate/671.data
#   inflating: generate/1047.data
#   inflating: generate/85.data
#   inflating: generate/250.data
#   inflating: generate/1404.data
#   inflating: generate/354.data
#   inflating: generate/494.data
#   inflating: generate/1568.data
#   inflating: generate/1318.data
#   inflating: generate/1549.data
#   inflating: generate/1286.data
#   inflating: generate/940.data
#   inflating: generate/1521.data
#   inflating: generate/1593.data
#   inflating: generate/221.data
#   inflating: generate/874.data
#   inflating: generate/39.data
#   inflating: generate/1141.data
#   inflating: generate/1624.data
#   inflating: generate/819.data
#   inflating: generate/498.data
#   inflating: generate/984.data
#   inflating: generate/645.data
#   inflating: generate/1257.data
#   inflating: generate/298.data
#   inflating: generate/225.data
#   inflating: generate/91.data
#   inflating: generate/1059.data
#   inflating: generate/1513.data
#   inflating: generate/1113.data
#   inflating: generate/380.data
#   inflating: generate/310.data
#   inflating: generate/1560.data
#   inflating: generate/185.data
#   inflating: generate/719.data
#   inflating: generate/433.data
#   inflating: generate/324.data
#   inflating: generate/1591.data
#   inflating: generate/300.data
#   inflating: generate/689.data
#   inflating: generate/1138.data
#   inflating: generate/1499.data
#   inflating: generate/1434.data
#   inflating: generate/594.data
#   inflating: generate/158.data
#   inflating: generate/706.data
#   inflating: generate/105.data
#   inflating: generate/46.data
#   inflating: generate/1041.data
#   inflating: generate/641.data
#   inflating: generate/690.data
#   inflating: generate/1039.data
#   inflating: generate/118.data
#   inflating: generate/845.data
#   inflating: generate/291.data
#   inflating: generate/1558.data
#   inflating: generate/846.data
#   inflating: generate/540.data
#   inflating: generate/1144.data
#   inflating: generate/1382.data
#   inflating: generate/1526.data
#   inflating: generate/809.data
#   inflating: generate/1476.data
#   inflating: generate/1606.data
#   inflating: generate/318.data
#   inflating: generate/1061.data
#   inflating: generate/1444.data
#   inflating: generate/964.data
#   inflating: generate/687.data
#   inflating: generate/694.data
#   inflating: generate/379.data
#   inflating: generate/430.data
#   inflating: generate/307.data
#   inflating: generate/901.data
#   inflating: generate/930.data
#   inflating: generate/763.data
#   inflating: generate/280.data
#   inflating: generate/1066.data
#   inflating: generate/775.data
#   inflating: generate/1304.data
#   inflating: generate/765.data
#   inflating: generate/1338.data
#   inflating: generate/702.data
#   inflating: generate/175.data
#   inflating: generate/402.data
#   inflating: generate/658.data
#   inflating: generate/253.data
#   inflating: generate/1191.data
#   inflating: generate/1070.data
#   inflating: generate/285.data
#   inflating: generate/154.data
#   inflating: generate/95.data
#   inflating: generate/266.data
#   inflating: generate/1053.data
#   inflating: generate/268.data
#   inflating: generate/194.data
#   inflating: generate/672.data
#   inflating: generate/1272.data
#   inflating: generate/1301.data
#   inflating: generate/100.data
#   inflating: generate/376.data
#   inflating: generate/1072.data
#   inflating: generate/44.data
#   inflating: generate/1050.data
#   inflating: generate/1166.data
#   inflating: generate/1360.data
#   inflating: generate/1125.data
#   inflating: generate/1400.data
#   inflating: generate/1497.data
#   inflating: generate/267.data
#   inflating: generate/783.data
#   inflating: generate/909.data
#   inflating: generate/1167.data
#   inflating: generate/969.data
#   inflating: generate/359.data
#   inflating: generate/1561.data
#   inflating: generate/1094.data
#   inflating: generate/1514.data
#   inflating: generate/51.data
#   inflating: generate/366.data
#   inflating: generate/552.data
#   inflating: generate/1580.data
#   inflating: generate/1109.data
#   inflating: generate/1320.data
#   inflating: generate/1309.data
#   inflating: generate/1452.data
#   inflating: generate/1256.data
#   inflating: generate/726.data
#   inflating: generate/1401.data
#   inflating: generate/611.data
#   inflating: generate/1135.data
#   inflating: generate/1498.data
#   inflating: generate/125.data
#   inflating: generate/1343.data
#   inflating: generate/514.data
#   inflating: generate/1120.data
#   inflating: generate/1615.data
#   inflating: generate/468.data
#   inflating: generate/591.data
#   inflating: generate/381.data
#   inflating: generate/368.data
#   inflating: generate/235.data
#   inflating: generate/949.data
#   inflating: generate/1170.data
#   inflating: generate/1630.data
#   inflating: generate/533.data
#   inflating: generate/577.data
#   inflating: generate/1600.data
#   inflating: generate/897.data
#   inflating: generate/785.data
#   inflating: generate/174.data
#   inflating: generate/428.data
#   inflating: generate/1429.data
#   inflating: generate/26.data
#   inflating: generate/1040.data
#   inflating: generate/1595.data
#   inflating: generate/427.data
#   inflating: generate/623.data
#   inflating: generate/693.data
#   inflating: generate/661.data
#   inflating: generate/1362.data
#   inflating: generate/583.data
#   inflating: generate/507.data
#   inflating: generate/239.data
#   inflating: generate/1282.data
#   inflating: generate/420.data
#   inflating: generate/385.data
#   inflating: generate/1644.data
#   inflating: generate/1576.data
#   inflating: generate/247.data
#   inflating: generate/1092.data
#   inflating: generate/1545.data
#   inflating: generate/1567.data
#   inflating: generate/1544.data
#   inflating: generate/1507.data
#   inflating: generate/242.data
#   inflating: generate/596.data
#   inflating: generate/1336.data
#   inflating: generate/234.data
#   inflating: generate/792.data
#   inflating: generate/1229.data
#   inflating: generate/1098.data
#   inflating: generate/345.data
#   inflating: generate/575.data
#   inflating: generate/1564.data
#   inflating: generate/1213.data
#   inflating: generate/457.data
#   inflating: generate/1112.data
#   inflating: generate/618.data
#   inflating: generate/680.data
#   inflating: generate/516.data
#   inflating: generate/553.data
#   inflating: generate/1661.data
#   inflating: generate/574.data
#   inflating: generate/831.data
#   inflating: generate/382.data
#   inflating: generate/1390.data
#   inflating: generate/454.data
#   inflating: generate/305.data
#   inflating: generate/200.data
#   inflating: generate/374.data
#   inflating: generate/321.data
#   inflating: generate/429.data
#   inflating: generate/10.data
#   inflating: generate/1292.data
#   inflating: generate/625.data
#   inflating: generate/484.data
#   inflating: generate/7.data
#   inflating: generate/973.data
#   inflating: generate/209.data
#   inflating: generate/796.data
#   inflating: generate/967.data
#  extracting: generate/1662.data
#   inflating: generate/569.data
#   inflating: generate/64.data
#   inflating: generate/1114.data
#   inflating: generate/1541.data
#   inflating: generate/1575.data
#   inflating: generate/535.data
#   inflating: generate/1611.data
#   inflating: generate/528.data
#   inflating: generate/1547.data
#   inflating: generate/263.data
#   inflating: generate/963.data
#   inflating: generate/789.data
#   inflating: generate/943.data
#   inflating: generate/864.data
#   inflating: generate/371.data
#   inflating: generate/43.data
#   inflating: generate/1015.data
#   inflating: generate/1164.data
#   inflating: generate/653.data
#   inflating: generate/486.data
#   inflating: generate/1375.data
#   inflating: generate/98.data
#   inflating: generate/0.data
#   inflating: generate/416.data
#   inflating: generate/133.data
#   inflating: generate/1010.data
#   inflating: generate/1693.data
#   inflating: generate/717.data
#   inflating: generate/1111.data
#   inflating: generate/718.data
#   inflating: generate/511.data
#   inflating: generate/1690.data
#   inflating: generate/572.data
#   inflating: generate/52.data
#   inflating: generate/715.data
#   inflating: generate/1245.data
#   inflating: generate/888.data
#   inflating: generate/1324.data
#   inflating: generate/989.data
#   inflating: generate/1086.data
#   inflating: generate/820.data
#   inflating: generate/502.data
#   inflating: generate/1123.data
#   inflating: generate/1605.data
#   inflating: generate/1185.data
#   inflating: generate/721.data
#   inflating: generate/1485.data
#   inflating: generate/489.data
#   inflating: generate/544.data
#   inflating: generate/141.data
#   inflating: generate/555.data
#   inflating: generate/29.data
#   inflating: generate/339.data
#   inflating: generate/804.data
#   inflating: generate/1448.data
#   inflating: generate/163.data
#   inflating: generate/281.data
#   inflating: generate/956.data
#   inflating: generate/1322.data
#   inflating: generate/1530.data
#   inflating: generate/460.data
#   inflating: generate/920.data
#   inflating: generate/1681.data
#   inflating: generate/222.data
#   inflating: generate/415.data
#   inflating: generate/1543.data
#   inflating: generate/215.data
#   inflating: generate/916.data
#   inflating: generate/417.data
#   inflating: generate/1196.data
#   inflating: generate/1491.data
#   inflating: generate/999.data
#   inflating: generate/868.data
#   inflating: generate/1674.data
#   inflating: generate/1667.data
#   inflating: generate/289.data
#   inflating: generate/1333.data
#   inflating: generate/1168.data
#   inflating: generate/149.data
#   inflating: generate/562.data
#   inflating: generate/237.data
#   inflating: generate/620.data
#   inflating: generate/629.data
#   inflating: generate/82.data
#   inflating: generate/757.data
#   inflating: generate/619.data
#   inflating: generate/770.data
#   inflating: generate/63.data
#   inflating: generate/983.data
#   inflating: generate/1679.data
#   inflating: generate/1150.data
#   inflating: generate/165.data
#   inflating: generate/414.data
#   inflating: generate/439.data
#   inflating: generate/399.data
#   inflating: generate/1698.data
#   inflating: generate/637.data
#   inflating: generate/309.data
#   inflating: generate/388.data
#   inflating: generate/1262.data
#   inflating: generate/508.data
#   inflating: generate/1181.data
#   inflating: generate/742.data
#   inflating: generate/341.data
#   inflating: generate/1019.data
#   inflating: generate/753.data
#   inflating: generate/1285.data
#   inflating: generate/360.data
#   inflating: generate/912.data
#   inflating: generate/627.data
#   inflating: generate/524.data
#   inflating: generate/1278.data
#   inflating: generate/447.data
#   inflating: generate/1563.data
#   inflating: generate/475.data
#   inflating: generate/1612.data
#   inflating: generate/173.data
#   inflating: generate/557.data
#   inflating: generate/42.data
#   inflating: generate/772.data
#   inflating: generate/1421.data
#   inflating: generate/362.data
#   inflating: generate/31.data
#   inflating: generate/183.data
#   inflating: generate/947.data
#   inflating: generate/1695.data
#   inflating: generate/589.data
#   inflating: generate/395.data
#   inflating: generate/608.data
#   inflating: generate/873.data
#   inflating: generate/1532.data
#   inflating: generate/107.data
#   inflating: generate/1267.data
#   inflating: generate/602.data
#   inflating: generate/459.data
#   inflating: generate/756.data
#   inflating: generate/1189.data
#   inflating: generate/1034.data
#   inflating: generate/352.data
#   inflating: generate/621.data
#   inflating: generate/1037.data
#   inflating: generate/1470.data
#   inflating: generate/276.data
#   inflating: generate/1386.data
#   inflating: generate/981.data
#   inflating: generate/1406.data
#   inflating: generate/1643.data
#   inflating: generate/1538.data
#   inflating: generate/1579.data
#   inflating: generate/803.data
#   inflating: generate/304.data
#   inflating: generate/405.data
#  extracting: generate/1658.data
#   inflating: generate/840.data
#   inflating: generate/455.data
#   inflating: generate/503.data
#   inflating: generate/180.data
#   inflating: generate/226.data
#   inflating: generate/1057.data
#   inflating: generate/603.data
#   inflating: generate/219.data
#   inflating: generate/1058.data
#   inflating: generate/413.data
#   inflating: generate/951.data
#   inflating: generate/1487.data
#   inflating: generate/924.data
#   inflating: generate/860.data
#   inflating: generate/101.data
#   inflating: generate/145.data
#   inflating: generate/1399.data
#   inflating: generate/1459.data
#   inflating: generate/1486.data
#   inflating: generate/480.data
#   inflating: generate/1102.data
#   inflating: generate/205.data
#   inflating: generate/902.data
#   inflating: generate/1266.data
#   inflating: generate/1241.data
#   inflating: generate/50.data
#   inflating: generate/724.data
#   inflating: generate/958.data
#   inflating: generate/960.data
#   inflating: generate/401.data
#   inflating: generate/1043.data
#   inflating: generate/914.data
#   inflating: generate/957.data
#   inflating: generate/394.data
#   inflating: generate/418.data
#   inflating: generate/1298.data
#   inflating: generate/1254.data
#   inflating: generate/795.data
#   inflating: generate/275.data
#   inflating: generate/176.data
#   inflating: generate/113.data
#   inflating: generate/1637.data
#   inflating: generate/292.data
#  extracting: generate/1652.data
#   inflating: generate/768.data
#   inflating: generate/301.data
#   inflating: generate/156.data
#   inflating: generate/830.data
#   inflating: generate/1342.data
#   inflating: generate/678.data
#   inflating: generate/787.data
#   inflating: generate/1582.data
#   inflating: generate/363.data
#   inflating: generate/748.data
#   inflating: generate/1420.data
#   inflating: generate/408.data
#   inflating: generate/720.data
#   inflating: generate/284.data
#   inflating: generate/729.data
#   inflating: generate/727.data
#   inflating: generate/1283.data
#   inflating: generate/1539.data
#   inflating: generate/1503.data
#   inflating: generate/1492.data
#   inflating: generate/1.data
#   inflating: generate/722.data
#   inflating: generate/615.data
#   inflating: generate/972.data
#   inflating: generate/700.data
#   inflating: generate/520.data
#   inflating: generate/1664.data
#   inflating: generate/204.data
#   inflating: generate/62.data
#   inflating: generate/836.data
#   inflating: generate/70.data
#   inflating: generate/593.data
#   inflating: generate/662.data
#   inflating: generate/223.data
#   inflating: generate/1315.data
#   inflating: generate/878.data
#   inflating: generate/325.data
#   inflating: generate/323.data
#   inflating: generate/78.data
#   inflating: generate/1504.data
#   inflating: generate/1008.data
#   inflating: generate/1392.data
#   inflating: generate/132.data
#   inflating: generate/1377.data
#   inflating: generate/274.data
#   inflating: generate/634.data
#   inflating: generate/961.data
#   inflating: generate/743.data
#   inflating: generate/492.data
#   inflating: generate/939.data
#   inflating: generate/1173.data
#   inflating: generate/595.data
#   inflating: generate/134.data
#   inflating: generate/534.data
#   inflating: generate/1645.data
#   inflating: generate/1162.data
#   inflating: generate/1614.data
#   inflating: generate/601.data
#   inflating: generate/432.data
#   inflating: generate/1028.data
#   inflating: generate/1161.data
#   inflating: generate/518.data
#   inflating: generate/384.data
#   inflating: generate/908.data
#   inflating: generate/900.data
#   inflating: generate/1023.data
#   inflating: generate/74.data
#   inflating: generate/1193.data
#   inflating: generate/217.data
#   inflating: generate/1493.data
#   inflating: generate/277.data
#   inflating: generate/1671.data
#   inflating: generate/1583.data
#   inflating: generate/1347.data
#   inflating: generate/1381.data
#   inflating: generate/1346.data
#   inflating: generate/462.data
#   inflating: generate/1018.data
#   inflating: generate/1411.data
#   inflating: generate/192.data
#   inflating: generate/178.data
#   inflating: generate/1512.data
#   inflating: generate/1451.data
#   inflating: generate/1557.data
#   inflating: generate/1011.data
#   inflating: generate/1153.data
#   inflating: generate/737.data
#   inflating: generate/358.data
#   inflating: generate/1130.data
#   inflating: generate/207.data
#   inflating: generate/828.data
#   inflating: generate/1474.data
#   inflating: generate/1317.data
#   inflating: generate/744.data
#   inflating: generate/387.data
#   inflating: generate/396.data
#   inflating: generate/1007.data
#   inflating: generate/1631.data
#   inflating: generate/1331.data
#   inflating: generate/815.data
#   inflating: generate/288.data
#   inflating: generate/581.data
#   inflating: generate/48.data
#   inflating: generate/181.data
#   inflating: generate/841.data
#   inflating: generate/224.data
#   inflating: generate/871.data
#   inflating: generate/630.data
#   inflating: generate/151.data
#   inflating: generate/1632.data
#   inflating: generate/1290.data
#   inflating: generate/1388.data
#   inflating: generate/466.data
#   inflating: generate/858.data
#   inflating: generate/1436.data
#   inflating: generate/259.data
#   inflating: generate/75.data
#   inflating: generate/681.data
#   inflating: generate/691.data
#   inflating: generate/758.data
#   inflating: generate/451.data
#   inflating: generate/53.data
#   inflating: generate/849.data
#   inflating: generate/129.data
#   inflating: generate/541.data
#   inflating: generate/1158.data
#   inflating: generate/996.data
#   inflating: generate/313.data
#   inflating: generate/1464.data
#   inflating: generate/1042.data
#   inflating: generate/1300.data
#   inflating: generate/1214.data
#   inflating: generate/764.data
#   inflating: generate/319.data
#   inflating: generate/473.data
#   inflating: generate/1174.data
#   inflating: generate/1105.data
#   inflating: generate/692.data
#   inflating: generate/992.data
#   inflating: generate/755.data
#   inflating: generate/1163.data
#   inflating: generate/1660.data
#   inflating: generate/513.data
#   inflating: generate/1233.data
#   inflating: generate/372.data
#   inflating: generate/778.data
#   inflating: generate/1424.data
#   inflating: generate/1433.data
#   inflating: generate/386.data
#   inflating: generate/1277.data
#   inflating: generate/517.data
#   inflating: generate/1187.data
#   inflating: generate/1550.data
#   inflating: generate/1481.data
#   inflating: generate/45.data
#   inflating: generate/1457.data
#   inflating: generate/1288.data
#   inflating: generate/883.data
#   inflating: generate/1571.data
#   inflating: generate/1035.data
#   inflating: generate/1169.data
#   inflating: generate/1198.data
#   inflating: generate/673.data
#   inflating: generate/1074.data
#   inflating: generate/1330.data
#   inflating: generate/752.data
#   inflating: generate/938.data
#   inflating: generate/1090.data
#   inflating: generate/807.data
#   inflating: generate/622.data
#   inflating: generate/278.data
#   inflating: generate/412.data
#   inflating: generate/1586.data
#   inflating: generate/945.data
#   inflating: generate/1516.data
#   inflating: generate/1425.data
#   inflating: generate/257.data
#   inflating: generate/351.data
#   inflating: generate/696.data
#   inflating: generate/1279.data
#   inflating: generate/195.data
#   inflating: generate/1103.data
#   inflating: generate/1472.data
#   inflating: generate/1207.data
#   inflating: generate/990.data
#   inflating: generate/79.data
#   inflating: generate/1551.data
#   inflating: generate/1048.data
#   inflating: generate/12.data
#   inflating: generate/110.data
#   inflating: generate/1508.data
#   inflating: generate/898.data
#   inflating: generate/739.data
#   inflating: generate/1055.data
#   inflating: generate/851.data
#   inflating: generate/699.data
#   inflating: generate/708.data
#   inflating: generate/1501.data
#   inflating: generate/1379.data
#   inflating: generate/357.data
#   inflating: generate/1312.data
#   inflating: generate/1699.data
#   inflating: generate/808.data
#   inflating: generate/890.data
#   inflating: generate/974.data
#   inflating: generate/1255.data
#   inflating: generate/90.data
#   inflating: generate/208.data
#   inflating: generate/245.data
#   inflating: generate/965.data
#   inflating: generate/723.data
#   inflating: generate/1427.data
#   inflating: generate/272.data
#   inflating: generate/612.data
#   inflating: generate/206.data
#   inflating: generate/1675.data
#   inflating: generate/1389.data
#   inflating: generate/213.data
#   inflating: generate/893.data
#   inflating: generate/613.data
#   inflating: generate/80.data
#   inflating: generate/952.data
#   inflating: generate/832.data
#   inflating: generate/786.data
#   inflating: generate/1638.data
#   inflating: generate/1287.data
#   inflating: generate/1291.data
#   inflating: generate/812.data
#   inflating: generate/1517.data
#   inflating: generate/1116.data
#   inflating: generate/1321.data
#   inflating: generate/1069.data
#   inflating: generate/523.data
#   inflating: generate/598.data
#   inflating: generate/1232.data
#   inflating: generate/1625.data
#   inflating: generate/355.data
#   inflating: generate/1608.data
#   inflating: generate/211.data
#   inflating: generate/683.data
#   inflating: generate/861.data
#   inflating: generate/929.data
#   inflating: generate/458.data
#   inflating: generate/801.data
#   inflating: generate/390.data
#   inflating: generate/937.data
#   inflating: generate/483.data
#   inflating: generate/1273.data
#   inflating: generate/479.data
#   inflating: generate/1284.data
#   inflating: generate/287.data
#   inflating: generate/1509.data
#   inflating: generate/1078.data
#   inflating: generate/1253.data
#   inflating: generate/112.data
#   inflating: generate/975.data
#   inflating: generate/114.data
#   inflating: generate/1552.data
#   inflating: generate/1510.data
#   inflating: generate/398.data
#   inflating: generate/1208.data
#   inflating: generate/1519.data
#   inflating: generate/102.data
#   inflating: generate/342.data
#   inflating: generate/1065.data
#   inflating: generate/115.data
#   inflating: generate/230.data
#   inflating: generate/333.data
#   inflating: generate/1139.data
#   inflating: generate/1477.data
#   inflating: generate/1106.data
#   inflating: generate/515.data
#   inflating: generate/9.data
#   inflating: generate/1310.data
#   inflating: generate/383.data
#   inflating: generate/1484.data
#   inflating: generate/252.data
#   inflating: generate/950.data
#   inflating: generate/1363.data
#   inflating: generate/1297.data
#   inflating: generate/985.data
#   inflating: generate/303.data
#   inflating: generate/889.data
#   inflating: generate/1045.data
#   inflating: generate/231.data
#   inflating: generate/578.data
#   inflating: generate/1159.data
#   inflating: generate/443.data
#   inflating: generate/800.data
#   inflating: generate/1395.data
#   inflating: generate/656.data
#   inflating: generate/531.data
#   inflating: generate/1160.data
#   inflating: generate/509.data
#   inflating: generate/1154.data
#   inflating: generate/1117.data
#   inflating: generate/4.data
#   inflating: generate/838.data
#   inflating: generate/340.data
#   inflating: generate/1657.data
#   inflating: generate/1430.data
#   inflating: generate/1268.data
#   inflating: generate/1371.data
#   inflating: generate/315.data
#   inflating: generate/664.data
#   inflating: generate/282.data
#   inflating: generate/411.data
#   inflating: generate/1394.data
#   inflating: generate/639.data
#   inflating: generate/13.data
#   inflating: generate/1589.data
#   inflating: generate/123.data
#   inflating: generate/1642.data
#   inflating: generate/35.data
#   inflating: generate/283.data
#   inflating: generate/306.data
#   inflating: generate/936.data
#   inflating: generate/1627.data
#   inflating: generate/880.data
#   inflating: generate/1296.data
#   inflating: generate/1691.data
#   inflating: generate/135.data
#   inflating: generate/876.data
#   inflating: generate/1646.data
#   inflating: generate/71.data
#   inflating: generate/1495.data
#   inflating: generate/712.data
#   inflating: generate/1124.data
#   inflating: generate/214.data
#   inflating: generate/1518.data
#   inflating: generate/1327.data
#   inflating: generate/1063.data
#   inflating: generate/865.data
#   inflating: generate/548.data
#   inflating: generate/995.data
#   inflating: generate/1602.data
#   inflating: generate/942.data
#   inflating: generate/903.data
#   inflating: generate/65.data
#   inflating: generate/532.data
#   inflating: generate/822.data
#   inflating: generate/740.data
#   inflating: generate/1559.data
#   inflating: generate/667.data
#   inflating: generate/1192.data
#   inflating: generate/1556.data
#   inflating: generate/1350.data
#   inflating: generate/444.data
#   inflating: generate/771.data
#   inflating: generate/1365.data
#   inflating: generate/193.data
#   inflating: generate/1194.data
#   inflating: generate/364.data
#   inflating: generate/1083.data
#   inflating: generate/1293.data
#   inflating: generate/1005.data
#   inflating: generate/710.data
#   inflating: generate/713.data
#   inflating: generate/934.data
#   inflating: generate/449.data
#   inflating: generate/877.data
#   inflating: generate/1428.data
#   inflating: generate/403.data
#   inflating: generate/537.data
#   inflating: generate/852.data
#   inflating: generate/604.data
#   inflating: generate/1210.data
#   inflating: generate/172.data
#   inflating: generate/37.data
#   inflating: generate/1145.data
#   inflating: generate/1502.data
#   inflating: generate/1180.data
#   inflating: generate/66.data
#   inflating: generate/767.data
#   inflating: generate/406.data
#   inflating: generate/251.data
#   inflating: generate/128.data
#   inflating: generate/1613.data
#   inflating: generate/1212.data
#   inflating: generate/698.data
#   inflating: generate/316.data
#   inflating: generate/472.data
#   inflating: generate/1131.data
#   inflating: generate/1603.data
#   inflating: generate/369.data
#   inflating: generate/1682.data
#   inflating: generate/155.data
#   inflating: generate/701.data
#   inflating: generate/1178.data
#   inflating: generate/1303.data
#   inflating: generate/1634.data
#   inflating: generate/491.data
#   inflating: generate/465.data
#   inflating: generate/116.data
#   inflating: generate/1441.data
#   inflating: generate/906.data
#   inflating: generate/1129.data
#   inflating: generate/202.data
#   inflating: generate/1534.data
#   inflating: generate/910.data
#   inflating: generate/169.data
#   inflating: generate/1263.data
#   inflating: generate/970.data
#   inflating: generate/270.data
#   inflating: generate/144.data
#   inflating: generate/668.data
#   inflating: generate/446.data
#   inflating: generate/1337.data
#   inflating: generate/697.data
#   inflating: generate/1598.data
#   inflating: generate/375.data
#   inflating: generate/1218.data
#   inflating: generate/1361.data
#   inflating: generate/228.data
#   inflating: generate/1080.data
#   inflating: generate/1076.data
#   inflating: generate/450.data
#   inflating: generate/1087.data
#   inflating: generate/1146.data
#   inflating: generate/769.data
#   inflating: generate/1249.data
#   inflating: generate/121.data
#   inflating: generate/189.data
#  extracting: generate/1677.data
#   inflating: generate/184.data
#   inflating: generate/790.data
#   inflating: generate/1414.data
#   inflating: generate/1460.data
#   inflating: generate/850.data
#   inflating: generate/3.data
#   inflating: generate/297.data
#   inflating: generate/1184.data
#   inflating: generate/731.data
#   inflating: generate/393.data
#   inflating: generate/160.data
#   inflating: generate/882.data
#   inflating: generate/1482.data
#   inflating: generate/140.data
#   inflating: generate/409.data
#   inflating: generate/590.data
#   inflating: generate/997.data
#   inflating: generate/30.data
#   inflating: generate/675.data
#   inflating: generate/1412.data
#   inflating: generate/1413.data
#   inflating: generate/923.data
#   inflating: generate/423.data
#   inflating: generate/442.data
#   inflating: generate/1468.data
#   inflating: generate/1251.data
#   inflating: generate/1209.data
#   inflating: generate/1183.data
#   inflating: generate/614.data
#   inflating: generate/571.data
#   inflating: generate/322.data
#   inflating: generate/816.data
#   inflating: generate/1110.data
#   inflating: generate/1276.data
#   inflating: generate/426.data
#   inflating: generate/1307.data
#   inflating: generate/558.data
#   inflating: generate/559.data
#   inflating: generate/1500.data
#   inflating: generate/674.data
#   inflating: generate/203.data
#   inflating: generate/1511.data
#   inflating: generate/760.data
#   inflating: generate/94.data
#   inflating: generate/884.data
#   inflating: generate/554.data
#   inflating: generate/218.data
#   inflating: generate/747.data
#   inflating: generate/1280.data
#   inflating: generate/1235.data
#   inflating: generate/1017.data
#   inflating: generate/1505.data
#   inflating: generate/1093.data
#   inflating: generate/1368.data
#   inflating: generate/1463.data
#   inflating: generate/1525.data
#   inflating: generate/654.data
#   inflating: generate/978.data
#   inflating: generate/1446.data
#   inflating: generate/1051.data
#   inflating: generate/915.data
#   inflating: generate/348.data
#   inflating: generate/68.data
#   inflating: generate/917.data
#   inflating: generate/857.data
#   inflating: generate/302.data
#   inflating: generate/805.data
#   inflating: generate/1566.data
#   inflating: generate/1391.data
#   inflating: generate/57.data
#   inflating: generate/1085.data
#   inflating: generate/810.data
#   inflating: generate/1230.data
#   inflating: generate/774.data
#   inflating: generate/20.data
#   inflating: generate/781.data
#   inflating: generate/1668.data
#   inflating: generate/953.data
#   inflating: generate/585.data
#   inflating: generate/1669.data
#   inflating: generate/16.data
#   inflating: generate/642.data
#   inflating: generate/370.data
#   inflating: generate/36.data
#   inflating: generate/1275.data
#   inflating: generate/14.data
#   inflating: generate/1376.data
#   inflating: generate/1574.data
#   inflating: generate/519.data
#   inflating: generate/536.data
#   inflating: generate/1670.data
#   inflating: generate/648.data
#   inflating: generate/1383.data
#   inflating: generate/927.data
#   inflating: generate/349.data
#   inflating: generate/600.data
#   inflating: generate/109.data
#   inflating: generate/1136.data
#   inflating: generate/490.data
#   inflating: generate/1000.data
#   inflating: generate/607.data
#   inflating: generate/1101.data
#   inflating: generate/1405.data
#   inflating: generate/1672.data
#   inflating: generate/41.data
#   inflating: generate/431.data
#   inflating: generate/365.data
#   inflating: generate/1021.data
#   inflating: generate/1134.data
#   inflating: generate/1422.data
#   inflating: generate/1473.data
#   inflating: generate/869.data
#   inflating: generate/640.data
#   inflating: generate/896.data
#   inflating: generate/435.data
#   inflating: generate/1351.data
#   inflating: generate/895.data
#   inflating: generate/464.data
#   inflating: generate/1528.data
#   inflating: generate/525.data
#   inflating: generate/99.data
#   inflating: generate/190.data
#   inflating: generate/1029.data
#   inflating: generate/311.data
#   inflating: generate/979.data
#   inflating: generate/1523.data
#   inflating: generate/738.data
#   inflating: generate/643.data
#   inflating: generate/925.data
#   inflating: generate/438.data
#   inflating: generate/264.data
#   inflating: generate/5.data
#   inflating: generate/1659.data
#   inflating: generate/1006.data
#   inflating: generate/227.data
#   inflating: generate/725.data
#   inflating: generate/659.data
#   inflating: generate/453.data
#   inflating: generate/157.data
#   inflating: generate/1587.data
#   inflating: generate/802.data
#   inflating: generate/1380.data
#   inflating: generate/1635.data
#   inflating: generate/1151.data
#   inflating: generate/265.data
#   inflating: generate/199.data
#   inflating: generate/872.data
#   inflating: generate/1240.data
#   inflating: generate/1206.data
#   inflating: generate/407.data
#   inflating: generate/730.data
#   inflating: generate/23.data
#   inflating: generate/566.data
#   inflating: generate/32.data
#   inflating: generate/1623.data
#   inflating: generate/1250.data
#   inflating: generate/1258.data
#   inflating: generate/456.data
#   inflating: generate/1244.data
#   inflating: generate/881.data
#   inflating: generate/1594.data
#   inflating: generate/1494.data
#   inflating: generate/338.data
#   inflating: generate/551.data
#   inflating: generate/1641.data
#   inflating: generate/11.data
#   inflating: generate/1478.data
#   inflating: generate/478.data
#   inflating: generate/1609.data
#   inflating: generate/563.data
#   inflating: generate/1316.data
#   inflating: generate/679.data
#   inflating: generate/152.data
#   inflating: generate/22.data
#   inflating: generate/1465.data
#   inflating: generate/941.data
#   inflating: generate/751.data
#   inflating: generate/1522.data
#   inflating: generate/148.data
#   inflating: generate/1217.data
#   inflating: generate/735.data
#   inflating: generate/966.data
#   inflating: generate/1341.data
#   inflating: generate/714.data
#   inflating: generate/1195.data
#   inflating: generate/980.data
#   inflating: generate/986.data
#   inflating: generate/545.data
#   inflating: generate/1071.data
#   inflating: generate/124.data
#   inflating: generate/448.data
#   inflating: generate/835.data
#   inflating: generate/998.data
#   inflating: generate/312.data
#   inflating: generate/646.data
#   inflating: generate/1016.data
#   inflating: generate/842.data
#   inflating: generate/1088.data
#   inflating: generate/1205.data
#   inflating: generate/461.data
#   inflating: generate/959.data
#   inflating: generate/422.data
#   inflating: generate/588.data
#   inflating: generate/1299.data
#   inflating: generate/1607.data
#   inflating: generate/1416.data
#   inflating: generate/867.data
#   inflating: generate/1407.data
#   inflating: generate/421.data
#   inflating: generate/249.data
#   inflating: generate/826.data
#   inflating: generate/854.data
#   inflating: generate/791.data
#   inflating: generate/859.data
#   inflating: generate/171.data
#   inflating: generate/709.data
#   inflating: generate/746.data
#   inflating: generate/1650.data
#   inflating: generate/317.data
#   inflating: generate/108.data
#   inflating: generate/1108.data
#   inflating: generate/1648.data
#   inflating: generate/1617.data
#   inflating: generate/686.data
#   inflating: generate/69.data
#   inflating: generate/196.data
#   inflating: generate/410.data
#   inflating: generate/279.data
#   inflating: generate/1546.data
#   inflating: generate/1335.data
#   inflating: generate/570.data
#   inflating: generate/463.data
#   inflating: generate/526.data
#   inflating: generate/797.data
#   inflating: generate/609.data
#   inflating: generate/1137.data
#   inflating: generate/220.data
#   inflating: generate/1014.data
#   inflating: generate/434.data
#   inflating: generate/547.data
#   inflating: generate/436.data
#   inflating: generate/142.data
#   inflating: generate/255.data
#   inflating: generate/546.data
#   inflating: generate/1200.data
#   inflating: generate/1025.data
#   inflating: generate/233.data
#   inflating: generate/573.data
#   inflating: generate/331.data
#   inflating: generate/1119.data
#   inflating: generate/1387.data
#   inflating: generate/346.data
#   inflating: generate/1524.data
#   inflating: generate/343.data
#   inflating: generate/1156.data
#   inflating: generate/856.data
#   inflating: generate/567.data
#   inflating: generate/1091.data
#   inflating: generate/1385.data
#   inflating: generate/512.data
#   inflating: generate/1454.data
#   inflating: generate/1046.data
#   inflating: generate/1520.data
#   inflating: generate/1121.data
#   inflating: generate/96.data
#   inflating: generate/539.data
#   inflating: generate/248.data
#   inflating: generate/1553.data
#   inflating: generate/474.data
#   inflating: generate/212.data
#   inflating: generate/243.data
#   inflating: generate/705.data
#   inflating: generate/741.data
#   inflating: generate/1097.data
#   inflating: generate/695.data
#   inflating: generate/1148.data
#   inflating: generate/469.data
#   inflating: generate/471.data
#   inflating: generate/1215.data
#   inflating: generate/238.data
#   inflating: generate/260.data
#   inflating: generate/954.data
#   inflating: generate/1535.data
#   inflating: generate/1222.data
#   inflating: generate/688.data
#   inflating: generate/1619.data
#   inflating: generate/262.data
#   inflating: generate/649.data
#   inflating: generate/1099.data
#   inflating: generate/837.data
#   inflating: generate/485.data
#   inflating: generate/378.data
#   inflating: generate/1572.data
#   inflating: generate/256.data
#   inflating: generate/1469.data
#   inflating: generate/504.data
#   inflating: generate/1685.data
#   inflating: generate/419.data
#   inflating: generate/529.data
#   inflating: generate/86.data
#   inflating: generate/482.data
#   inflating: generate/84.data
#   inflating: generate/685.data
#   inflating: generate/1393.data
#   inflating: generate/1402.data
#   inflating: generate/21.data
#   inflating: generate/799.data
#   inflating: generate/510.data
#   inflating: generate/711.data
#   inflating: generate/655.data
#   inflating: generate/437.data
#   inflating: generate/1537.data
#   inflating: generate/1013.data
#   inflating: generate/626.data
#   inflating: generate/1259.data
#   inflating: generate/497.data
#   inflating: generate/784.data
#   inflating: generate/49.data
#   inflating: generate/17.data
#   inflating: generate/843.data
#   inflating: generate/261.data
#   inflating: generate/1364.data
#   inflating: generate/592.data
#   inflating: generate/663.data
#   inflating: generate/1432.data
#   inflating: generate/913.data
#  extracting: generate/1653.data
#   inflating: generate/1221.data
#   inflating: generate/994.data
#   inflating: generate/1649.data
#   inflating: generate/1031.data
#   inflating: generate/1462.data
#   inflating: generate/269.data
#   inflating: generate/1339.data
#   inflating: generate/1592.data
#   inflating: generate/666.data
#   inflating: generate/605.data
#   inflating: generate/1107.data
#   inflating: generate/777.data
#   inflating: generate/1633.data
#   inflating: generate/821.data
#   inflating: generate/1252.data
#   inflating: generate/1243.data
#   inflating: generate/1265.data
#   inflating: generate/1588.data
#   inflating: generate/106.data
#   inflating: generate/495.data
#   inflating: generate/624.data
#   inflating: generate/1270.data
#   inflating: generate/391.data
#   inflating: generate/326.data
#   inflating: generate/170.data
#   inflating: generate/1480.data
#   inflating: generate/1696.data
#   inflating: generate/81.data
#   inflating: generate/1694.data
#   inflating: generate/894.data
#   inflating: generate/232.data
#   inflating: generate/1100.data
#   inflating: generate/1408.data
#   inflating: generate/1610.data
#   inflating: generate/1599.data
#   inflating: generate/1128.data
#   inflating: generate/1073.data
#   inflating: generate/1629.data
#   inflating: generate/1636.data
#   inflating: generate/1628.data
#   inflating: generate/1096.data
#   inflating: generate/1248.data
#   inflating: generate/1027.data
#   inflating: generate/1417.data
#   inflating: generate/1435.data
# ...
#   inflating: generate/891.data
#   inflating: generate/153.data
#   inflating: generate/147.data
#   inflating: generate/1439.data
#   inflating: generate/1372.data
#   inflating: generate/1220.data
#   inflating: generate/97.data
#   inflating: generate/1155.data
#   inflating: generate/1663.data
#   inflating: generate/682.data
#   inflating: generate/707.data
#   inflating: generate/793.data
#   inflating: generate/77.data
#   inflating: generate/813.data
#   inflating: generate/1075.data
#   inflating: generate/117.data
#   inflating: generate/24.data
#   inflating: generate/122.data
#   inflating: generate/187.data
#   inflating: generate/1165.data
#   inflating: generate/1329.data
#   inflating: generate/27.data
#   inflating: generate/1306.data
#   inflating: generate/1068.data
#   inflating: generate/445.data
#   inflating: generate/76.data
#   inflating: generate/1683.data
#   inflating: generate/1450.data
#   inflating: generate/186.data
#   inflating: generate/1358.data
#   inflating: generate/1203.data
#   inflating: generate/1149.data
#   inflating: generate/83.data
#   inflating: generate/111.data
#   inflating: generate/34.data
#   inflating: generate/467.data
#   inflating: generate/1461.data
#   inflating: generate/1079.data
#   inflating: generate/1224.data
#   inflating: generate/556.data
#   inflating: generate/617.data
#   inflating: generate/1626.data
#   inflating: generate/1199.data
#   inflating: generate/295.data
#   inflating: generate/628.data
#   inflating: generate/392.data
#   inflating: generate/779.data
#   inflating: generate/258.data
#   inflating: generate/294.data
#   inflating: generate/522.data
#   inflating: generate/568.data
#   inflating: generate/734.data
#   inflating: generate/1581.data
#   inflating: generate/1673.data
#   inflating: generate/1359.data
#   inflating: generate/1225.data
#   inflating: generate/561.data
#   inflating: generate/334.data
#   inflating: generate/863.data
#   inflating: generate/866.data
#   inflating: generate/1246.data
#   inflating: generate/886.data
#   inflating: generate/766.data
#   inflating: generate/40.data
#   inflating: generate/1366.data
#   inflating: generate/1449.data
#   inflating: generate/1038.data
#   inflating: generate/1003.data
#   inflating: generate/1374.data
#   inflating: generate/944.data
#   inflating: generate/2.data
#   inflating: generate/55.data
#   inflating: generate/652.data
#   inflating: generate/271.data
#   inflating: generate/210.data
#   inflating: generate/1471.data
#   inflating: generate/632.data
#   inflating: generate/1666.data
#   inflating: generate/1355.data
#   inflating: generate/1030.data
#   inflating: generate/829.data
#   inflating: generate/1622.data
#   inflating: generate/441.data
#   inflating: generate/347.data
#   inflating: generate/1490.data
#   inflating: generate/926.data
#   inflating: generate/977.data
#   inflating: generate/1077.data
#   inflating: generate/844.data
#  extracting: generate/1684.data
#   inflating: generate/905.data
#   inflating: generate/88.data
#   inflating: generate/241.data
#   inflating: generate/505.data
#   inflating: generate/164.data
#   inflating: generate/332.data
#   inflating: generate/610.data
#   inflating: generate/788.data
#   inflating: generate/1127.data
#   inflating: generate/885.data
#   inflating: generate/73.data
#   inflating: generate/476.data
#   inflating: generate/373.data
#   inflating: generate/1001.data
#   inflating: generate/126.data
#   inflating: generate/1067.data
#   inflating: generate/1197.data
#   inflating: generate/932.data
#   inflating: generate/794.data
#   inflating: generate/162.data
#   inflating: generate/1052.data
#   inflating: generate/58.data
#   inflating: generate/806.data
#   inflating: generate/1104.data
#   inflating: generate/759.data
#   inflating: generate/521.data
#   inflating: generate/500.data
#   inflating: generate/1601.data
#   inflating: generate/1264.data
#   inflating: generate/273.data
#   inflating: generate/1095.data
#   inflating: generate/350.data
#   inflating: generate/182.data
#   inflating: generate/296.data
#   inflating: generate/389.data
#   inflating: generate/1515.data
#   inflating: generate/1157.data
#   inflating: generate/6.data
#   inflating: generate/1049.data
#   inflating: generate/38.data
#   inflating: generate/1344.data
#   inflating: generate/1453.data
#   inflating: generate/1475.data
#   inflating: generate/229.data
#   inflating: generate/1655.data
#   inflating: generate/1569.data
#   inflating: generate/1352.data
#  extracting: generate/1692.data
#   inflating: generate/586.data
#   inflating: generate/1118.data
#   inflating: generate/56.data
#   inflating: generate/1640.data
#   inflating: generate/1247.data
#   inflating: generate/817.data
#   inflating: generate/1319.data
#   inflating: generate/1188.data
#   inflating: generate/1370.data
#   inflating: generate/1570.data
#   inflating: generate/1020.data
#   inflating: generate/1458.data
#   inflating: generate/293.data
#   inflating: generate/127.data
#   inflating: generate/584.data
#   inflating: generate/1033.data
#   inflating: generate/1234.data
#   inflating: generate/104.data
#   inflating: generate/971.data
#   inflating: generate/1578.data
#   inflating: generate/911.data
#   inflating: generate/1009.data
#   inflating: generate/1410.data
#   inflating: generate/335.data
#   inflating: generate/1345.data
#   inflating: generate/1483.data
#   inflating: generate/290.data
#   inflating: generate/798.data
#   inflating: generate/131.data
#   inflating: generate/904.data
#   inflating: generate/19.data
#   inflating: generate/1024.data
#   inflating: generate/1584.data
#   inflating: generate/922.data
#   inflating: generate/716.data
#   inflating: generate/1687.data
#   inflating: generate/1540.data
#   inflating: generate/811.data
#   inflating: generate/60.data
#   inflating: generate/824.data
#   inflating: generate/146.data
#   inflating: generate/1548.data
#   inflating: generate/1621.data
#   inflating: generate/1242.data
#   inflating: generate/1573.data
#   inflating: generate/377.data
#   inflating: generate/704.data
#   inflating: generate/1398.data
#   inflating: generate/968.data
#   inflating: generate/1651.data
#   inflating: generate/703.data
#   inflating: generate/827.data
#   inflating: generate/1369.data
#   inflating: generate/201.data
#   inflating: generate/166.data
#   inflating: generate/481.data
#   inflating: generate/631.data
#   inflating: generate/216.data
#   inflating: generate/356.data
#   inflating: generate/616.data
#   inflating: generate/1678.data
#   inflating: generate/1056.data
#   inflating: generate/834.data
#   inflating: generate/425.data
#   inflating: generate/1384.data
#   inflating: generate/138.data
#   inflating: generate/814.data
#   inflating: generate/244.data
#   inflating: generate/1295.data
#   inflating: generate/93.data
#   inflating: generate/1489.data
#   inflating: generate/550.data
#   inflating: generate/1340.data
#   inflating: generate/955.data
#   inflating: generate/1447.data
#   inflating: generate/579.data
#   inflating: generate/745.data
#   inflating: generate/527.data
#   inflating: generate/159.data
#   inflating: generate/452.data
#   inflating: generate/25.data
#   inflating: generate/1349.data
#   inflating: generate/506.data
#   inflating: generate/1311.data
#   inflating: generate/320.data
#   inflating: generate/1239.data
#   inflating: generate/1274.data
#   inflating: generate/1201.data
#   inflating: generate/397.data
#   inflating: generate/1426.data
#   inflating: generate/1680.data
#   inflating: generate/1271.data
#   inflating: generate/935.data
#   inflating: generate/1437.data
#   inflating: generate/1596.data
#   inflating: generate/1639.data
#   inflating: generate/353.data
#   inflating: generate/400.data
#   inflating: generate/1328.data
#   inflating: generate/1132.data
#   inflating: generate/847.data
#   inflating: generate/54.data
#   inflating: generate/1294.data
#   inflating: generate/647.data
#   inflating: generate/404.data
#   inflating: generate/1177.data
#   inflating: generate/1353.data
#   inflating: generate/1060.data
#   inflating: generate/1555.data
#   inflating: generate/538.data
#   inflating: generate/1562.data
#   inflating: generate/853.data
#   inflating: generate/191.data
#   inflating: generate/543.data
#   inflating: generate/887.data
#   inflating: generate/1260.data
#   inflating: generate/470.data
#   inflating: generate/1467.data
#   inflating: generate/582.data
#   inflating: generate/1506.data
#   inflating: generate/1618.data
#   inflating: generate/18.data
#   inflating: generate/1115.data
#   inflating: generate/1032.data
#   inflating: generate/197.data
#   inflating: generate/1357.data
#   inflating: generate/1367.data
#   inflating: generate/1533.data
#   inflating: generate/948.data
#   inflating: generate/1423.data
#   inflating: generate/1565.data
#   inflating: generate/493.data
#   inflating: generate/136.data
#   inflating: generate/907.data
#   inflating: generate/103.data
#   inflating: generate/773.data
#   inflating: generate/344.data
#   inflating: generate/1536.data
#   inflating: generate/638.data
#   inflating: generate/736.data
#   inflating: generate/1036.data
#   inflating: generate/1415.data
#   inflating: generate/732.data
#   inflating: generate/644.data
#   inflating: generate/599.data
#   inflating: generate/361.data
#   inflating: generate/1590.data
#   inflating: generate/750.data
#   inflating: generate/1269.data
#   inflating: generate/587.data
#   inflating: generate/1334.data
#   inflating: generate/130.data
#   inflating: generate/137.data
#   inflating: generate/1289.data
#   inflating: generate/1665.data
#   inflating: generate/1140.data
#   inflating: generate/1620.data
#   inflating: generate/33.data
#  extracting: generate/1686.data
#   inflating: generate/684.data
#   inflating: generate/818.data
#   inflating: generate/1577.data
#   inflating: generate/1143.data
#   inflating: generate/1403.data
#   inflating: generate/143.data
#   inflating: generate/1419.data
#   inflating: generate/1529.data
#   inflating: generate/749.data
#   inflating: generate/1604.data
#   inflating: generate/1182.data
#   inflating: generate/597.data
#   inflating: generate/991.data
#   inflating: generate/670.data
#   inflating: generate/501.data
#   inflating: generate/669.data
#   inflating: generate/246.data
#   inflating: generate/1373.data
#   inflating: generate/1488.data
#   inflating: generate/179.data
#   inflating: generate/987.data
#   inflating: generate/1231.data
#   inflating: generate/677.data
#   inflating: generate/1438.data
#   inflating: generate/120.data
#   inflating: generate/1084.data
#   inflating: generate/1409.data
#   inflating: generate/1332.data
#   inflating: generate/870.data
#   inflating: generate/1186.data
#   inflating: generate/1211.data
#   inflating: generate/530.data
#   inflating: generate/1190.data
#   inflating: generate/823.data
#   inflating: generate/1044.data
#   inflating: generate/1418.data
#   inflating: generate/236.data
#   inflating: generate/1172.data
#   inflating: generate/1082.data
#   inflating: generate/1305.data
#   inflating: generate/499.data
#   inflating: generate/59.data
#   inflating: generate/47.data
#   inflating: generate/564.data
#   inflating: generate/1302.data
#   inflating: generate/728.data
#   inflating: generate/580.data
#   inflating: generate/1004.data
#   inflating: generate/198.data
#   inflating: generate/1261.data
#   inflating: generate/1223.data
#   inflating: generate/754.data
#   inflating: generate/299.data
#   inflating: generate/542.data
#   inflating: generate/1227.data
#   inflating: generate/733.data
#   inflating: generate/919.data
#   inflating: generate/327.data
#   inflating: generate/660.data
#   inflating: generate/1236.data
#   inflating: generate/855.data
#   inflating: generate/780.data
#   inflating: generate/892.data
#   inflating: generate/633.data
#   inflating: generate/1378.data
#   inflating: generate/982.data
#   inflating: generate/1281.data
#   inflating: generate/1314.data
#   inflating: generate/1654.data
#   inflating: generate/150.data
#   inflating: generate/928.data
#   inflating: generate/336.data
#   inflating: generate/1176.data
#   inflating: generate/1348.data
#   inflating: generate/1455.data
#   inflating: generate/565.data
#   inflating: generate/761.data
#   inflating: generate/1062.data
#   inflating: generate/8.data
#   inflating: generate/962.data
#   inflating: generate/28.data
#   inflating: generate/254.data
#   inflating: generate/496.data
#   inflating: generate/1147.data
#   inflating: generate/119.data
#   inflating: generate/1445.data
#   inflating: generate/1531.data
#   inflating: generate/1142.data
#   inflating: generate/776.data
#   inflating: generate/477.data
#   inflating: generate/1527.data
#   inflating: generate/549.data
#   inflating: generate/330.data
#   inflating: generate/424.data
#   inflating: generate/1326.data
#   inflating: generate/15.data
#   inflating: generate/1022.data
#   inflating: generate/1226.data
#   inflating: generate/862.data
#   inflating: generate/1354.data
#   inflating: generate/657.data
#   inflating: generate/1585.data
#   inflating: generate/139.data
#   inflating: generate/1313.data
#   inflating: generate/1325.data
#   inflating: generate/161.data
#   inflating: generate/1179.data
#   inflating: generate/314.data
#   inflating: generate/1122.data
#   inflating: generate/576.data
#   inflating: generate/1237.data
#   inflating: generate/1479.data
#   inflating: generate/1089.data
#   inflating: generate/1440.data
#   inflating: generate/1456.data
#   inflating: generate/329.data
#   inflating: generate/1466.data
#   inflating: generate/92.data
#   inflating: generate/488.data
#   inflating: generate/988.data
#   inflating: generate/782.data
#   inflating: generate/1397.data
#   inflating: generate/177.data
#   inflating: generate/825.data

# %%
import os

nbData = 1000

moveKatago = []
color = []
evalKatago = []

moveData = []
priorMove = []
scoreData = []

for i in range (nbData):
    name = "generate/" + str (i) + ".data"
    if os.path.exists(name):
        fichier = open(name, "r")
        #print ('read' + name)                                                                                                                                                                              
        state = []
        label = [x for x in next(fichier).split()] # read first line                                                                                                                                        
        moveKatago.append (int (label [0]))
        color.append (label [1])
        evalKatago.append (float (label [2]))
        values = [x for x in next(fichier).split()]
        moves = []
        priors = []
        scores = []
        for i in range (10):
            values = [x for x in next(fichier).split()]
            moves.append (int (values [0]))
            priors.append (float (values [1]))
            nb = int (values [2])
            l = []
            for j in range (3, len (values)):
                l.append (float (values [j]))
            scores.append (l)
        fichier.close ()
        moveData.append (moves)
        priorMove.append (priors)
        scoreData.append (scores)
    else:
        print ('pb reading', name)

print (len(moveData))
# Out:
# 1000

# %%
import copy
import numpy as np

def bestHalf (moves, sumScores, nbPlayouts):
    half = []
    notused = list(np.full(361,True))
    for x in range (int(np.ceil(len (moves) / 2))):
        best = -1.0
        bestMove = moves [0]
        for m in moves:
            if notused [m]:
                mu = sumScores [m] / nbPlayouts [m]
                if mu > best:
                    best = mu
                    bestMove = m
        notused [bestMove] = False
        half.append (bestMove)
    return half

count = 0
for i in range (len (moveData)):
    moves = copy.deepcopy (moveData [i])
    total = 128
    nbPlayouts = [0 for x in range (361)]
    sumScores = [0.0 for x in range (361)]
    while (len (moves) > 1):
        for m in moves:
            bestj = 0
            for j in range (len (moveData [i])):
                if m == moveData [i] [j]:
                    bestj = j
            for j in range (max (1, int (nb // (len (moves) * np.log2 (total))))):
                value = scoreData [i] [bestj] [nbPlayouts [m]]
                if color [i] == 'b':
                    value = 1 - value
                sumScores [m] += value
                nbPlayouts [m] += 1
        moves = bestHalf (moves, sumScores, nbPlayouts)                                                                                                                                            
    if moves [0] == moveKatago [i]:
        count = count + 1
print ('score SH =', count)
# Out:
# score SH = 162

# %%
import copy
import numpy as np

atoms = ['+', '*', 'sc', 'pr', '2']
children = [2, 2, 0, 0, 0]
MaxLength = 7

def legalMoves (state, leaves):
    l = []
    for a in range (len (atoms)):
        if len (state) + leaves + children [a] <= MaxLength:
            l.append (a)
    return l

def play (state, move, leaves):
    state.append (move)
    return [state, leaves - 1 + children [move]]

def terminal (state, leaves):
    return leaves == 0

def playout (state, leaves):
    while not terminal (state, leaves):
        moves = legalMoves (state, leaves)
        move = moves [int(random.random () * len (moves))]
        [state, leaves] = play (state, move, leaves)
    return state

def score (state, i, prior, sumScores):
    if children [state [i]] == 0:
        if state [i] == '2':
            return [2, i + 1]
        if state [i] == 'sc':
            return [sumScores, i + 1]
        if state [i] == 'pr':
            return [prior, i + 1]
    if children [state [i]] == 2:
        a = atoms [state [i]]
        [s1,i] = score (state, i + 1, prior, sumScores)
        [s2,i] = score (state, i, prior, sumScores)
        if a == '+':
            return [s1 + s2, i]
        if a == '*':
            return [s1 * s2, i]
        
def bestHalf (moves, sumScores, nbPlayouts, expression, prior):
    half = []
    notused = list(np.full(361,True))
    for x in range (int(np.ceil(len (moves) / 2))):
        best = -1.0
        bestMove = moves [0]
        for m in moves:
            if notused [m]:
                mu = score (expression, 0, prior [m], sumScores [m])
                if mu > best:
                    best = mu
                    bestMove = m
        notused [bestMove] = False
        half.append (bestMove)
    return half

def evaluate (expression):
    count = 0
    for i in range (len (moveData)):
        moves = copy.deepcopy (moveData [i])
        total = 128
        nbPlayouts = [0 for x in range (361)]
        sumScores = [0.0 for x in range (361)]
        priors = [0.0 for x in range (361)]
        while (len (moves) > 1):
            for m in moves:
                bestj = 0
                for j in range (len (moveData [i])):
                    if m == moveData [i] [j]:
                        bestj = j
                priors [m] = priorMove [i] [bestj]
                for j in range (max (1, int (nb // (len (moves) * np.log2 (total))))):
                    value = scoreData [i] [bestj] [nbPlayouts [m]]
                    if color [i] == 'b':
                        value = 1 - value
                    sumScores [m] += value
                    nbPlayouts [m] += 1
            moves = bestHalf (moves, sumScores, nbPlayouts, expression, priors)                                                                                                                                            
        if moves [0] == moveKatago [i]:
            count = count + 1
    return count

print ('score SH =', evaluate (['sc']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 88
#      85             count = count + 1
#      86     return count
# ---> 88 print ('score SH =', evaluate (['sc']))
#
# Cell In[9], line 83, in evaluate(expression)
#      81             sumScores [m] += value
#      82             nbPlayouts [m] += 1
# ---> 83     moves = bestHalf (moves, sumScores, nbPlayouts, expression, priors)
#      84 if moves [0] == moveKatago [i]:
#      85     count = count + 1
#
# Cell In[9], line 54, in bestHalf(moves, sumScores, nbPlayouts, expression, prior)
#      52 for m in moves:
#      53     if notused [m]:
# ---> 54         mu = score (expression, 0, prior [m], sumScores [m])
#      55         if mu > best:
#      56             best = mu
#
# Cell In[9], line 30, in score(state, i, prior, sumScores)
#      29 def score (state, i, prior, sumScores):
# ---> 30     if children [state [i]] == 0:
#      31         if state [i] == '2':
#      32             return [2, i + 1]
#
# TypeError: list indices must be integers or slices, not str
