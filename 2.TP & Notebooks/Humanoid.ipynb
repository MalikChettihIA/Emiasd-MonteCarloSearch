# %%
# !pip install gymnasium
# !pip install mujoco
# !pip install imageio
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.1.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from gymnasium) (1.26.4)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from gymnasium) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.21.0)
# Downloading gymnasium-1.1.1-py3-none-any.whl (965 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 6.6 MB/s eta 0:00:00
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, cloudpickle, gymnasium
# Successfully installed cloudpickle-3.1.1 farama-notifications-0.0.4 gymnasium-1.1.1
# Collecting mujoco
#   Downloading mujoco-3.3.6-cp39-cp39-macosx_11_0_arm64.whl.metadata (41 kB)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from mujoco) (2.1.0)
# Collecting etils[epath] (from mujoco)
#   Downloading etils-1.5.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting glfw (from mujoco)
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from mujoco) (1.26.4)
# Collecting pyopengl (from mujoco)
#   Downloading pyopengl-3.1.10-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from etils[epath]->mujoco)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: importlib_resources in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from etils[epath]->mujoco) (6.5.2)
# Requirement already satisfied: typing_extensions in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from etils[epath]->mujoco) (4.12.2)
# Requirement already satisfied: zipp in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from etils[epath]->mujoco) (3.21.0)
# Downloading mujoco-3.3.6-cp39-cp39-macosx_11_0_arm64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 8.9 MB/s eta 0:00:00a 0:00:01m
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-macosx_11_0_arm64.whl (102 kB)
# Downloading pyopengl-3.1.10-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 12.2 MB/s eta 0:00:00a 0:00:01
# Downloading etils-1.5.2-py3-none-any.whl (140 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Installing collected packages: pyopengl, glfw, fsspec, etils, mujoco
# Successfully installed etils-1.5.2 fsspec-2025.9.0 glfw-2.10.0 mujoco-3.3.6 pyopengl-3.1.10
# Collecting imageio
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from imageio) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in /opt/anaconda3/envs/emiasd-deeplearning2-env/lib/python3.9/site-packages (from imageio) (11.1.0)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Installing collected packages: imageio
# Successfully installed imageio-2.37.0

# %%
import gymnasium as gym
import sys

env = gym.make('Humanoid-v5', ctrl_cost_weight=0.1, render_mode='human')

# Play 100 playouts and keep the best
bestSumReward = -1000
bestListActions = []
for i in range (10):
    observation, info = env.reset()
    terminated = False
    sumReward = 0
    listActions = []
    while not terminated:
        action = env.action_space.sample()
        listActions.append (action)

        # step (transition) through the environment with the action
        # receiving the next observation, reward and if the episode has terminated or truncated
        observation, reward, terminated, truncated, info = env.step(action)
        sumReward += reward
    sys.stdout.write (str (sumReward) + ' ')
    if sumReward > bestSumReward:
        bestSumReward = sumReward
        bestListActions = listActions
print ()
print (bestListActions)
print (bestSumReward)
env.close()
# Out:
